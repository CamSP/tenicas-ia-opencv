# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Carga de imagenes

# %%
cancer = cv2.imread("fig/Cancer.tif", 0)
not_cancer = cv2.imread("fig/Not Cancer.jpeg", 0)
plt.imshow(cancer, cmap="gray")
plt.figure()
plt.imshow(not_cancer, cmap="gray")

# %% [markdown]
# # División

# %% [markdown]
# # Mezcla

# %% [markdown]
# # Contornos

# %% [markdown]
# # Similitud

# %% [markdown]
# #
